# %%
LoadPackage("packageManager");

InstallPackage("https://github.com/le27/aaa.git");

LoadPackage("aaa");

JupyterSplashDot(DotTransducer(RandomTransducer(2, 3)));
# Out:
# #I  Created directory /home/gap/.gap/
# #I  Created directory /home/gap/.gap/pkg/
# #I  Cloning to /home/gap/.gap/pkg/aaa ...
# #I  Package cloned successfully
# #I  Checking dependencies for aaa...
# #I    automata >=0.0.0: true
# #I    digraphs >=0.15.0: true
# #I  WARNING: could not build doc (no makedoc.g or doc/make_doc)
# #E  component `HTMLStart' must be bound to a string denoting a relative path t\
# o a readable file
# #E  component `PDFFile' must be bound to a string denoting a relative path to \
# a readable file
# #E  component `SixFile' must be bound to a string denoting a relative path to \
# a readable file
# #I  PackageInfo.g validation failed
# #I  (in /home/gap/.gap/pkg/aaa)
# true
# false
# true

# %%
B:= Transducer(2, 2, [[1, 2], [1, 2]], [[[1], [0]], [[1], [0]]]);;

C:= Transducer(2, 2, [[1, 2], [1, 2]], [[[1], []], [[0,1], [0]]]);;

JupyterSplashDot(DotTransducer(B));

JupyterSplashDot(DotTransducer(C));

OmegaEquivalentTransducers(B, C);

IsomorphicTransducers(B, C);

B=C;
# Out:
# true
# false
# true

# %%
A:=AlphabetChangeTransducer(2, 3);;JupyterSplashDot(DotTransducer(A));

# %%
IdentityTransducer(2) = A*AlphabetChangeTransducer(3, 2);
# Out:
# true

# %%
T:=TransducerByNumber(2, 3, 7000);;JupyterSplashDot(DotTransducer(T));

# %%
IsDegenerateTransducer(A);

IsInjectiveTransducer(A);

IsSurjectiveTransducer(A);

IsBijectiveTransducer(A);

IsSynchronizingTransducer(A);

IsSynchronousTransducer(A);

IsDegenerateTransducer(T);

IsInjectiveTransducer(T);

IsSurjectiveTransducer(T);

IsBijectiveTransducer(T);

IsSynchronizingTransducer(T);

IsSynchronousTransducer(T);
# Out:
# false
# true
# true
# true
# false
# false
# false
# true
# false
# false
# false
# false

# %%
3letterT := T^A;;JupyterSplashDot(DotTransducer(T));

# %%
2letterT:=3letterT^AlphabetChangeTransducer(3, 2);;JupyterSplashDot(DotTransducer(2letterT));

# %%
JupyterSplashDot(DotTransducer(MinimalTransducer(2letterT)));

# %%
IsomorphicInitialTransducers(MinimalTransducer(2letterT), T);
# Out:
# true

# %%
JupyterSplashDot(DotTransducer(DeBruijnTransducer(2,3)));

# %%
JupyterSplashDot(DotTransducer(BlockCodeTransducer(2,3, x->[x[4]])));

# %%
IsomorphicTransducers(DeBruijnTransducer(2,3), BlockCodeTransducer(2,3, x->[x[4]]));
# Out:
# true

# %%
JupyterSplashDot(DotTransducer(BlockCodeTransducer(2,3, x->[x[1]])));

# %%
IsomorphicTransducers(DeBruijnTransducer(2,3), BlockCodeTransducer(2,3, x->[x[1]]));
# Out:
# false

# %%
P:= PrimeWordSwapTransducer(2, [1, 0, 0], [0, 1, 1]);;JupyterSplashDot(DotTransducer(P));

# %%
[1, 0, 0]^P; ActionOnNecklaces(3,P); [0]^P; ActionOnNecklaces(1,P); [0, 0, 0, 1]^P; ActionOnNecklaces(4,P);
# Out:
# [ 0, 1, 1 ]
# (1,2)
# [ 0 ]
# ()
# [ 0, 1, 0, 0 ]
# ()

# %%
IsSynchronizingTransducer(P); TransducerSynchronizingLength(P); IsSynchronousTransducer(P);
# Out:
# true
# 4
# true

# %%
M := MinimalTransducer(P);;JupyterSplashDot(DotTransducer(M));

# %%
IsSynchronizingTransducer(M); TransducerSynchronizingLength(M);IsSynchronousTransducer(M);IsLipschitzTransducer(M);
# Out:
# true
# 4
# false
# true

# %%
IsCoreTransducer(P); IsCoreTransducer(M); C:= TransducerCore(M);; IsCoreTransducer(C);
# Out:
# true
# false
# true

# %%
IsBisynchronizingTransducer(C);
# Out:
# true

# %%
JupyterSplashDot(DotTransducer(C));

# %%
C4:= CopyTransducerWithInitialState(C, 4);;JupyterSplashDot(DotTransducer(C4));

# %%
HasClopenImage(C);ImageAsUnionOfCones(C); ImageAsUnionOfCones(C4);
# Out:
# true
# [ [  ] ]
# [ [ 0, 0 ], [ 0, 1, 1 ], [ 1, 1, 0 ] ]

# %%
IsomorphicTransducers(C, C4);IsomorphicInitialTransducers(C, C4);
# Out:
# true
# false

# %%
InOn(C);InLn(C);
# Out:
# true
# true

# %%
IsLipschitzTransducer(C);JupyterSplashDot(DotTransducer(MinSyncSync(C)));
# Out:
# true

# %%
IsCompletableCore(P);F:=CoreCompletion(P); JupyterSplashDot(DotTransducer(F));
# Out:
# true

# %%
IsMinimalTransducer(F);
# Out:
# false

# %%
JupyterSplashDot(DotTransducer(MinimalTransducer(F)));

# %%
C2:= TransducerCore(MinimalTransducer(F));;JupyterSplashDot(DotTransducer(C2));

# %%
IsomorphicTransducers(C, C2);
# Out:
# true
