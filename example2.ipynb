# %%
LoadPackage("packageManager");

LoadPackage("aaa");

JupyterSplashDot(DotTransducer(RandomTransducer(2, 3)));
# Out:
# true
# true

# %%
A:=AlphabetChangeTransducer(2, 3);

# %%
JupyterSplashDot(DotTransducer(A));

# %%
T:=TransducerByNumber(2, 3, 7000);;JupyterSplashDot(DotTransducer(T));

# %%
IsDegenerateTransducer(A);

IsInjectiveTransducer(A);

IsSurjectiveTransducer(A);

IsBijectiveTransducer(A);

IsSynchronizingTransducer(A);

IsSynchronousTransducer(A);

IsDegenerateTransducer(T);

IsInjectiveTransducer(T);

IsSurjectiveTransducer(T);

IsBijectiveTransducer(T);

IsSynchronizingTransducer(T);

IsSynchronousTransducer(T);
# Out:
# Error, no method found! For debugging hints type ?Recovery from NoMethodFound
# Error, no 1st choice method found for `IsInjectiveTransducer' on 1 arguments at /home/gap/inst/gap-4.10.2/lib/methsel2.g:250 called from
# <function "HANDLE_METHOD_NOT_FOUND">( <arguments> )
#  called from read-eval loop at stream:1
# Error, no method found! For debugging hints type ?Recovery from NoMethodFound
# Error, no 1st choice method found for `IsSurjectiveTransducer' on 1 arguments at /home/gap/inst/gap-4.10.2/lib/methsel2.g:250 called from
# <function "HANDLE_METHOD_NOT_FOUND">( <arguments> )
#  called from read-eval loop at stream:3
# Error, no method found! For debugging hints type ?Recovery from NoMethodFound
# Error, no 1st choice method found for `IsBijectiveTransducer' on 1 arguments at /home/gap/inst/gap-4.10.2/lib/methsel2.g:250 called from
# <function "HANDLE_METHOD_NOT_FOUND">( <arguments> )
#  called from read-eval loop at stream:5
# Error, no method found! For debugging hints type ?Recovery from NoMethodFound
# Error, no 1st choice method found for `IsSynchronizingTransducer' on 1 arguments at /home/gap/inst/gap-4.10.2/lib/methsel2.g:250 called from
# <function "HANDLE_METHOD_NOT_FOUND">( <arguments> )
#  called from read-eval loop at stream:7
# Error, no method found! For debugging hints type ?Recovery from NoMethodFound
# Error, no 1st choice method found for `IsSynchronousTransducer' on 1 arguments at /home/gap/inst/gap-4.10.2/lib/methsel2.g:250 called from
# <function "HANDLE_METHOD_NOT_FOUND">( <arguments> )
#  called from read-eval loop at stream:9
# true
# false
# false
# false
# false

# %%
3letterT := T^A;;JupyterSplashDot(DotTransducer(T));

# %%
2letterT:=3letterT^AlphabetChangeTransducer(3, 2);;JupyterSplashDot(DotTransducer(2letterT));

# %%
JupyterSplashDot(DotTransducer(MinimalTransducer(2letterT)));

# %%
IsomorphicInitialTransducers(MinimalTransducer(2letterT), T);
# Out:
# true

# %%
JupyterSplashDot(DotTransducer(DeBruijnTransducer(2,3)));

# %%
JupyterSplashDot(DotTransducer(BlockCodeTransducer(2,3, x->[x[4]])));

# %%
IsomorphicTransducers(DeBruijnTransducer(2,3), BlockCodeTransducer(2,3, x->[x[4]]));
# Out:
# true

# %%
JupyterSplashDot(DotTransducer(BlockCodeTransducer(2,3, x->[x[1]])));

# %%
IsomorphicTransducers(DeBruijnTransducer(2,3), BlockCodeTransducer(2,3, x->[x[1]]));
# Out:
# false

# %%
P:= PrimeWordSwapTransducer(2, [1, 0, 0], [0, 1, 1]);;JupyterSplashDot(DotTransducer(P));

# %%
ActionOnNecklaces(P,2, 3);
# Out:
# Error, no method found! For debugging hints type ?Recovery from NoMethodFound
# Error, no 1st choice method found for `ActionOnNecklaces' on 3 arguments at /home/gap/inst/gap-4.10.2/lib/methsel2.g:250 called from
# <function "HANDLE_METHOD_NOT_FOUND">( <arguments> )
#  called from read-eval loop at stream:1
